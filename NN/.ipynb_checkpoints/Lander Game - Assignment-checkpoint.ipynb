# %% [markdown]
# # Lander Game - Assignment

# %% [markdown]
# ## To Do

# %% [markdown]
# - Normalise all variables
# - Delete any duplicates
# - Work out which variables are actually needed
# - Split (70/30) for training and test

# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("data.csv", names=['X Distance to Target', 'Y Distance to Target', 'Vel Y', 'Vel X'])

# %%
df
# Out:
#         X Distance to Target  Y Distance to Target     Vel Y    Vel X
# 0                 -26.719611            359.900000  0.000000  0.00000
# 1                 -26.719611            359.900000 -0.100000  0.04000
# 2                 -26.759611            360.000000 -0.200000  0.00000
# 3                 -26.759611            360.200000 -0.300000  0.04000
# 4                 -26.799611            360.500000 -0.400000  0.00000
# ...                      ...                   ...       ...      ...
# 102611              9.383350            103.215570  7.959786  0.22623
# 102612              9.157120             95.255784  7.959786  0.22623
# 102613              8.930890             87.295999  7.959786  0.22623
# 102614              8.704660             79.336213  7.959786  0.22623
# 102615              8.478430             71.376428  7.959786  0.22623
#
# [102616 rows x 4 columns]

# %%
X = df['X Distance to Target']
y = df['Vel X']
sns.scatterplot(X,y)
# Out:
# C:\Users\carte\miniconda3\envs\ce889\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='X Distance to Target', ylabel='Vel X'>

# %%
X = df['Y Distance to Target']
y = df['Vel Y']
sns.scatterplot(X,y)
# Out:
# C:\Users\carte\miniconda3\envs\ce889\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Y Distance to Target', ylabel='Vel Y'>

# %%
# if distance to target >0 & velocity < 0 delete, X distance to target is < 0 & velocity is > 0 

#updated_df = df[((df['X Distance to Target'] > 0) & (df['Vel X'] > 0)) | ((df['X Distance to Target'] < 0) & (df['Vel X'] < 0))]
#updated_df

def data_clean(df):
    # will get rid of any row without a value input.
    df.dropna(axis=0, how='any', inplace=True)
    # duplicates will be removed
    df.drop_duplicates(inplace=True)
    # for outliers outside 3 standard deviations from the mean, the row will be removed.
    return df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]

updated_df = data_clean(updated_df)

# %%
from sklearn import preprocessing

# %%
x = updated_df.values
min_max_scaler = preprocessing.MinMaxScaler()
norm = min_max_scaler.fit_transform(x)
norm_df = pd.DataFrame(norm)

norm_df
# Out:
#               0         1         2         3
# 0      0.479471  0.480097  0.300888  0.494594
# 1      0.479486  0.481528  0.292715  0.496002
# 2      0.479480  0.484919  0.276600  0.491390
# 3      0.479528  0.486876  0.268698  0.491273
# 4      0.479577  0.489004  0.260925  0.490655
# ...         ...       ...       ...       ...
# 85298  0.508957  0.138854  0.966855  0.533451
# 85299  0.508579  0.125860  0.975118  0.530503
# 85300  0.508230  0.112686  0.983382  0.527554
# 85301  0.507911  0.099334  0.991645  0.524606
# 85302  0.507622  0.085802  0.999908  0.521658
#
# [85303 rows x 4 columns]

# %%
input_df = norm_df[[0,1]]
input_df
# Out:
#               0         1
# 0      0.479471  0.480097
# 1      0.479486  0.481528
# 2      0.479480  0.484919
# 3      0.479528  0.486876
# 4      0.479577  0.489004
# ...         ...       ...
# 85298  0.508957  0.138854
# 85299  0.508579  0.125860
# 85300  0.508230  0.112686
# 85301  0.507911  0.099334
# 85302  0.507622  0.085802
#
# [85303 rows x 2 columns]

# %%
output_df = norm_df[[2,3]]
output_df
# Out:
#               2         3
# 0      0.300888  0.494594
# 1      0.292715  0.496002
# 2      0.276600  0.491390
# 3      0.268698  0.491273
# 4      0.260925  0.490655
# ...         ...       ...
# 85298  0.966855  0.533451
# 85299  0.975118  0.530503
# 85300  0.983382  0.527554
# 85301  0.991645  0.524606
# 85302  0.999908  0.521658
#
# [85303 rows x 2 columns]

# %%
output_df
# Out:
#               2         3
# 0      0.300888  0.494594
# 1      0.292715  0.496002
# 2      0.276600  0.491390
# 3      0.268698  0.491273
# 4      0.260925  0.490655
# ...         ...       ...
# 85298  0.966855  0.533451
# 85299  0.975118  0.530503
# 85300  0.983382  0.527554
# 85301  0.991645  0.524606
# 85302  0.999908  0.521658
#
# [85303 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(input_df, output_df, test_size=0.3, random_state=42)

# %%
X_train.to_csv("X_train2.csv", index=False, header=None)
X_test.to_csv("X_test2.csv", index=False, header=None)
y_train.to_csv("y_train2.csv", index=False, header=None)
y_test.to_csv("y_test2.csv", index=False, header=None)

# %%
X_train
# Out:
#               0         1
# 47546  0.271704  0.480707
# 54142  0.675158  0.886089
# 41031  0.488878  0.464037
# 47283  0.446345  0.599772
# 30787  0.454352  0.423248
# ...         ...       ...
# 6265   0.768271  0.515796
# 54886  0.532928  0.362595
# 76820  0.546492  0.652007
# 860    0.517871  0.205478
# 15795  0.803183  0.553019
#
# [59712 rows x 2 columns]

# %%
y_train
# Out:
#               2         3
# 47546  0.296270  0.427757
# 54142  0.339082  0.604511
# 41031  0.615525  0.255089
# 47283  0.345386  0.414911
# 30787  0.729684  0.354442
# ...         ...       ...
# 6265   0.378216  0.916407
# 54886  0.730632  0.535209
# 76820  0.471314  0.566109
# 860    0.628435  0.498589
# 15795  0.292349  0.823584
#
# [59712 rows x 2 columns]

# %%
X = norm_df[0]
y = norm_df[3]
sns.scatterplot(X,y)
# Out:
# C:\Users\carte\miniconda3\envs\ce889\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='0', ylabel='3'>
